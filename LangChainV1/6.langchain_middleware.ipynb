# %% [markdown]
# ### Middleware
#
# Middleware provides a way to more tightly control what happens inside the agent. Middleware is useful for the following:
# - Tracking agent behavior with logging, analytics, and debugging.
# - Transforming prompts, tool selection, and output formatting.
# - Adding retries, fallbacks, and early termination logic.
# - Applying rate limits, guardrails, and PII detection.

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')

# %% [markdown]
# ### Summarization MiddleWare
# Automatically summarize conversation history when approaching token limits, preserving recent messages while compressing older context. Summarization is useful for the following:
# - Long-running conversations that exceed context windows.
# - Multi-turn dialogues with extensive history.
# - Applications where preserving full conversation context matters.

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langgraph.checkpoint.memory import InMemorySaver
from langchain_core.messages import HumanMessage, SystemMessage

### Messagebased summarization
agent = create_agent(
    model= "gpt-5-mini-2025-08-07",
    checkpointer=InMemorySaver(),
    middleware=[
        SummarizationMiddleware(
            model="gpt-5",
            trigger=("messages", 10),
            keep=("messages", 4)
        )
    ]
)

# %%
### Run with thread id
config = {
    "configurable":{
        "thread_id":"test-1"
    }
}

# %%
# Alternative test data
questions = [
    "What is 2+2?",
    "What is 10*5?",
    "What is 100/4?",
    "What is 15-7?",
    "What is 3*3?",
    "What is 4*4?",
]

for q in questions:
    response = agent.invoke(
        {
            "messages":[
                HumanMessage(content=q),

            ]
        },
        config
    )

    print(f"Message: {response}")
    print(f"Message: {len(response['messages'])}")
# Out:
# Message: {'messages': [HumanMessage(content='Here is a summary of the conversation to date:\n\n- The user has been asking simple arithmetic questions; the assistant answers concisely in equation form.\n- Completed Q&As: 2+2=4 (asked twice); 10×5=50.\n- Latest user message (unanswered): “What is 100/4?”', additional_kwargs={}, response_metadata={}, id='90e4501b-7fbe-4198-acb8-4b1e3de3e21d'), AIMessage(content='100 ÷ 4 = 25.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 88, 'total_tokens': 106, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtsDMpqRSL9OJZsw9VAraU6d1thwO', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b832f-5565-7cb2-97de-0ba4dbcc578b-0', usage_metadata={'input_tokens': 88, 'output_tokens': 18, 'total_tokens': 106, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 15-7?', additional_kwargs={}, response_metadata={}, id='89e2b91f-01ba-4973-92b1-fec16d53cba6'), AIMessage(content='15 - 7 = 8.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 114, 'total_tokens': 131, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtsDPLPFTr4XwxIMZCltDOmpXgtXH', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b832f-600e-7f03-8d5b-40e9e2fddf79-0', usage_metadata={'input_tokens': 114, 'output_tokens': 17, 'total_tokens': 131, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 3*3?', additional_kwargs={}, response_metadata={}, id='dd091b5d-460f-4c8f-9f59-9a5f889d67b8'), AIMessage(content='3 * 3 = 9.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 126, 'total_tokens': 207, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtsDp4W2npsGDWRUli3YxgcDZAAOk', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b832f-c661-7eb2-9d13-ac97a5d86078-0', usage_metadata={'input_tokens': 126, 'output_tokens': 81, 'total_tokens': 207, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}), HumanMessage(content='What is 4*4?', additional_kwargs={}, response_metadata={}, id='beeed4f9-fc67-4c57-baef-46ab1ad49d57'), AIMessage(content='4 * 4 = 16.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 151, 'total_tokens': 168, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtsDsDAKZMCL3ZhJ0quOVYNBlAYO9', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b832f-d20f-7120-875b-abc5ac15d5fe-0', usage_metadata={'input_tokens': 151, 'output_tokens': 17, 'total_tokens': 168, ...
# Message: 10
# Message: {'messages': [HumanMessage(content='Here is a summary of the conversation to date:\n\n- User is asking simple arithmetic questions; prefers concise equation-form answers.\n- Completed Q&As: 2+2=4 (asked twice); 10×5=50; 100÷4=25; 15−7=8; 3×3=9.\n- Latest user message (unanswered): “What is 4*4?”', additional_kwargs={}, response_metadata={}, id='2376d855-bf87-4664-95fa-b1af695cdee8'), AIMessage(content='4 * 4 = 16.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 151, 'total_tokens': 168, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtsDsDAKZMCL3ZhJ0quOVYNBlAYO9', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b832f-d20f-7120-875b-abc5ac15d5fe-0', usage_metadata={'input_tokens': 151, 'output_tokens': 17, 'total_tokens': 168, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={}, id='3233ad87-b5d5-4262-bba7-3ecfebc0db6b'), AIMessage(content='2 + 2 = 4.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 145, 'prompt_tokens': 176, 'total_tokens': 321, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtsEqNqJUBnL6ZxUAgLcswNe0ui0M', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8330-bf6b-7ea1-b5c7-b73fe7abd58a-0', usage_metadata={'input_tokens': 176, 'output_tokens': 145, 'total_tokens': 321, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}), HumanMessage(content='What is 10*5?', additional_kwargs={}, response_metadata={}, id='0efb16e0-3aef-4df5-bdad-f79fc31a824e'), AIMessage(content='10 * 5 = 50.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 140, 'total_tokens': 157, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtsF4Gs71Tm0eL9eVvYiMd1CHFrh3', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8330-f5f9-7702-81bd-d728634552e4-0', usage_metadata={'input_tokens': 140, 'output_tokens': 17, 'total_tokens': 157, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# Message: 6
# Message: {'messages': [HumanMessage(content='Here is a summary of the conversation to date:\n\n- User is asking simple arithmetic questions; prefers concise equation-form answers.\n- Completed Q&As: 2+2=4 (asked twice); 10×5=50; 100÷4=25; 15−7=8; 3×3=9.\n- Latest user message (unanswered): “What is 4*4?”', additional_kwargs={}, response_metadata={}, id='2376d855-bf87-4664-95fa-b1af695cdee8'), AIMessage(content='4 * 4 = 16.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 151, 'total_tokens': 168, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtsDsDAKZMCL3ZhJ0quOVYNBlAYO9', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b832f-d20f-7120-875b-abc5ac15d5fe-0', usage_metadata={'input_tokens': 151, 'output_tokens': 17, 'total_tokens': 168, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={}, id='3233ad87-b5d5-4262-bba7-3ecfebc0db6b'), AIMessage(content='2 + 2 = 4.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 145, 'prompt_tokens': 176, 'total_tokens': 321, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtsEqNqJUBnL6ZxUAgLcswNe0ui0M', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8330-bf6b-7ea1-b5c7-b73fe7abd58a-0', usage_metadata={'input_tokens': 176, 'output_tokens': 145, 'total_tokens': 321, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}), HumanMessage(content='What is 10*5?', additional_kwargs={}, response_metadata={}, id='0efb16e0-3aef-4df5-bdad-f79fc31a824e'), AIMessage(content='10 * 5 = 50.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 140, 'total_tokens': 157, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtsF4Gs71Tm0eL9eVvYiMd1CHFrh3', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8330-f5f9-7702-81bd-d728634552e4-0', usage_metadata={'input_tokens': 140, 'output_tokens': 17, 'total_tokens': 157, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 100/4?', additional_kwargs={}, response_metadata={}, id='3a66d778-93f4-428e-828c-272b1a162934'), AIMessage(content='100 / 4 = 25', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 80, 'prompt_tokens': 165, 'total_tokens': 245, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtsF7q9WsQQQSzaNjIBBZAJ3oOd36', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8330-fe75-7263-a246-e69228ac0817-0', usage_metadata={'input_tokens': 165, 'output_tokens': 80, 'total_to ...
# Message: 8
# Message: {'messages': [HumanMessage(content='Here is a summary of the conversation to date:\n\n- User is asking simple arithmetic questions; prefers concise equation-form answers.\n- Completed Q&As: 2+2=4 (asked twice); 10×5=50; 100÷4=25; 15−7=8; 3×3=9.\n- Latest user message (unanswered): “What is 4*4?”', additional_kwargs={}, response_metadata={}, id='2376d855-bf87-4664-95fa-b1af695cdee8'), AIMessage(content='4 * 4 = 16.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 151, 'total_tokens': 168, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtsDsDAKZMCL3ZhJ0quOVYNBlAYO9', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b832f-d20f-7120-875b-abc5ac15d5fe-0', usage_metadata={'input_tokens': 151, 'output_tokens': 17, 'total_tokens': 168, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={}, id='3233ad87-b5d5-4262-bba7-3ecfebc0db6b'), AIMessage(content='2 + 2 = 4.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 145, 'prompt_tokens': 176, 'total_tokens': 321, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtsEqNqJUBnL6ZxUAgLcswNe0ui0M', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8330-bf6b-7ea1-b5c7-b73fe7abd58a-0', usage_metadata={'input_tokens': 176, 'output_tokens': 145, 'total_tokens': 321, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}), HumanMessage(content='What is 10*5?', additional_kwargs={}, response_metadata={}, id='0efb16e0-3aef-4df5-bdad-f79fc31a824e'), AIMessage(content='10 * 5 = 50.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 140, 'total_tokens': 157, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtsF4Gs71Tm0eL9eVvYiMd1CHFrh3', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8330-f5f9-7702-81bd-d728634552e4-0', usage_metadata={'input_tokens': 140, 'output_tokens': 17, 'total_tokens': 157, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 100/4?', additional_kwargs={}, response_metadata={}, id='3a66d778-93f4-428e-828c-272b1a162934'), AIMessage(content='100 / 4 = 25', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 80, 'prompt_tokens': 165, 'total_tokens': 245, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtsF7q9WsQQQSzaNjIBBZAJ3oOd36', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8330-fe75-7263-a246-e69228ac0817-0', usage_metadata={'input_tokens': 165, 'output_tokens': 80, 'total_to ...
# Message: 10
# Message: {'messages': [HumanMessage(content='Here is a summary of the conversation to date:\n\n- User preference: concise equation-form answers for simple arithmetic.\n- Completed Q&As: 2+2=4 (asked twice); 10*5=50; 15-7=8; 3*3=9; 4*4=16.\n- Latest user message (unanswered): "What is 100/4?"', additional_kwargs={}, response_metadata={}, id='7d57f517-07db-486c-8a88-3612440c0d99'), AIMessage(content='100 / 4 = 25', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 80, 'prompt_tokens': 165, 'total_tokens': 245, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtsF7q9WsQQQSzaNjIBBZAJ3oOd36', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8330-fe75-7263-a246-e69228ac0817-0', usage_metadata={'input_tokens': 165, 'output_tokens': 80, 'total_tokens': 245, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}), HumanMessage(content='What is 15-7?', additional_kwargs={}, response_metadata={}, id='b143b759-6162-4726-982e-7f12117b8089'), AIMessage(content='15 - 7 = 8', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 80, 'prompt_tokens': 189, 'total_tokens': 269, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtsFA5H3k5nMYjFTYpq29Vz01Blag', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8331-0a70-71f0-8a3f-589aa2cb8bcf-0', usage_metadata={'input_tokens': 189, 'output_tokens': 80, 'total_tokens': 269, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}), HumanMessage(content='What is 3*3?', additional_kwargs={}, response_metadata={}, id='d98871cd-f0ac-41d8-90b6-edf6bb525e34'), AIMessage(content='3 * 3 = 9', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 144, 'prompt_tokens': 136, 'total_tokens': 280, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtsFhaa43WMObM6F6GYvYkgigFuE3', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8331-8cbf-7b53-8b55-afd00b501b87-0', usage_metadata={'input_tokens': 136, 'output_tokens': 144, 'total_tokens': 280, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}})]}
# Message: 6
# Message: {'messages': [HumanMessage(content='Here is a summary of the conversation to date:\n\n- User preference: concise equation-form answers for simple arithmetic.\n- Completed Q&As: 2+2=4 (asked twice); 10*5=50; 15-7=8; 3*3=9; 4*4=16.\n- Latest user message (unanswered): "What is 100/4?"', additional_kwargs={}, response_metadata={}, id='7d57f517-07db-486c-8a88-3612440c0d99'), AIMessage(content='100 / 4 = 25', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 80, 'prompt_tokens': 165, 'total_tokens': 245, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtsF7q9WsQQQSzaNjIBBZAJ3oOd36', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8330-fe75-7263-a246-e69228ac0817-0', usage_metadata={'input_tokens': 165, 'output_tokens': 80, 'total_tokens': 245, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}), HumanMessage(content='What is 15-7?', additional_kwargs={}, response_metadata={}, id='b143b759-6162-4726-982e-7f12117b8089'), AIMessage(content='15 - 7 = 8', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 80, 'prompt_tokens': 189, 'total_tokens': 269, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtsFA5H3k5nMYjFTYpq29Vz01Blag', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8331-0a70-71f0-8a3f-589aa2cb8bcf-0', usage_metadata={'input_tokens': 189, 'output_tokens': 80, 'total_tokens': 269, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}), HumanMessage(content='What is 3*3?', additional_kwargs={}, response_metadata={}, id='d98871cd-f0ac-41d8-90b6-edf6bb525e34'), AIMessage(content='3 * 3 = 9', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 144, 'prompt_tokens': 136, 'total_tokens': 280, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtsFhaa43WMObM6F6GYvYkgigFuE3', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8331-8cbf-7b53-8b55-afd00b501b87-0', usage_metadata={'input_tokens': 136, 'output_tokens': 144, 'total_tokens': 280, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}), HumanMessage(content='What is 4*4?', additional_kwargs={}, response_metadata={}, id='c5ba6278-8525-4887-bf15-e306563eeb50'), AIMessage(content='4 * 4 = 16', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 160, 'total_tokens': 176, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtsFkvfKmc7oK8CesG6YUQN25kw4Z', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8331-98d5-75d1-af7b-b5fc1d53610a-0', usage_metadata={'input_tokens': 160, 'output_tokens': 16, 'total_tokens': 176, 'inp ...
# Message: 8

# %%
from langchain_core.tools import tool
@tool
def search_hotels(city: str)->str:
    """Search hotels - returns long response to use more tokens."""
    return f"""Hotels in {city}:
    1. Grand Hotel - 5 star, $350/night, spa, pool, gym
    2. City Inn - 4 star, $180/night, business center
    3. Budget Stay - 3 star, $75/night, free wifi"""

agent = create_agent(
    model = "gpt-5-mini-2025-08-07",
    checkpointer=InMemorySaver(),
    tools=[search_hotels],
    middleware=[
        SummarizationMiddleware(
            model="gpt-5",
            trigger=("tokens", 550),
            keep=("tokens",200)
        )
    ]
    
)

config = {"configurable": {"thread_id": "test-1"}}

# Token counter (approximate)
def count_tokens(messages):
    total_chars = sum(len(str(m.content)) for m in messages)
    return total_chars // 4  # 4 chars ≈ 1 token

# %%
# Run test
cities = ["Paris", "London", "Tokyo", "New York", "Dubai", "Singapore"]

for city in cities:
    response = agent.invoke(
        {
            "messages": [HumanMessage(content=f"Find hotels in {city}")],
            
        },
        config
    )

    tokens = count_tokens(response["messages"])
    print(f"{city}: ~{tokens} tokens, {len(response['messages'])} messages")
    print(f"{(response['messages'])}")
    print("***********************************")
# Out:
# Paris: ~193 tokens, 4 messages
# [HumanMessage(content='Find hotels in Paris', additional_kwargs={}, response_metadata={}, id='99c65e96-5534-4425-a328-f1dd25a453b1'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 134, 'total_tokens': 158, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CttlIr1g90QSDxzitTpEcpwsMjUsc', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b838a-174c-77b1-85b1-607e4ee957ea-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_D2IQZJn7jt3FHPDSkuP8UnCD', 'type': 'tool_call'}], usage_metadata={'input_tokens': 134, 'output_tokens': 24, 'total_tokens': 158, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Paris:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='28b86944-b090-4417-b8de-445fe4b0c29a', tool_call_id='call_D2IQZJn7jt3FHPDSkuP8UnCD'), AIMessage(content='I found these options in Paris:\n\n1. Grand Hotel — 5-star, $350/night. Amenities: spa, pool, gym. (Good for luxury stays and relaxation.)\n2. City Inn — 4-star, $180/night. Amenities: business center. (Good for business travelers or mid-range comfort.)\n3. Budget Stay — 3-star, $75/night. Amenities: free Wi‑Fi. (Good low-cost option.)\n\nNext steps — which would you like?\n- Tell me travel dates and number of guests and I’ll check availability and show room types/prices.\n- Or tell me preferred neighborhood, max price, or must-have amenities and I’ll filter/search more options.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 342, 'prompt_tokens': 224, 'total_tokens': 566, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CttlLqW6GmrOKOVzlKhBIGtM3N7xR', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b838a-24d5-7283-aca3-850b9a5fccf0-0', usage_metadata={'input_tokens': 224, 'output_tokens': 342, 'total_tokens': 566, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}})]
# ***********************************
# London: ~328 tokens, 8 messages
# [HumanMessage(content='Find hotels in Paris', additional_kwargs={}, response_metadata={}, id='99c65e96-5534-4425-a328-f1dd25a453b1'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 134, 'total_tokens': 158, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CttlIr1g90QSDxzitTpEcpwsMjUsc', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b838a-174c-77b1-85b1-607e4ee957ea-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_D2IQZJn7jt3FHPDSkuP8UnCD', 'type': 'tool_call'}], usage_metadata={'input_tokens': 134, 'output_tokens': 24, 'total_tokens': 158, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Paris:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='28b86944-b090-4417-b8de-445fe4b0c29a', tool_call_id='call_D2IQZJn7jt3FHPDSkuP8UnCD'), AIMessage(content='I found these options in Paris:\n\n1. Grand Hotel — 5-star, $350/night. Amenities: spa, pool, gym. (Good for luxury stays and relaxation.)\n2. City Inn — 4-star, $180/night. Amenities: business center. (Good for business travelers or mid-range comfort.)\n3. Budget Stay — 3-star, $75/night. Amenities: free Wi‑Fi. (Good low-cost option.)\n\nNext steps — which would you like?\n- Tell me travel dates and number of guests and I’ll check availability and show room types/prices.\n- Or tell me preferred neighborhood, max price, or must-have amenities and I’ll filter/search more options.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 342, 'prompt_tokens': 224, 'total_tokens': 566, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CttlLqW6GmrOKOVzlKhBIGtM3N7xR', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b838a-24d5-7283-aca3-850b9a5fccf0-0', usage_metadata={'input_tokens': 224, 'output_tokens': 342, 'total_tokens': 566, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}}), HumanMessage(content='Find hotels in London', additional_kwargs={}, response_metadata={}, id='e7a8288a-8958-424f-927b-1ccc85cc4532'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 88, 'prompt_tokens': 379, 'total_tokens': 467, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CttlSrSGXLDFfQS39tAIY4RasKfZo', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b838a-3d6a-7a72-8b58-083b47f2c2c6-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'London'}, 'id': 'call_QSJdV9iINueZnUqeEo581YhT', 'type': 'tool_call'}], usage_metadata={'input_tokens': 379, 'output_tokens': 88, 'total_tokens': 467, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}), ToolMessage(content='Hotels in London:\n    1. Grand Hotel - 5 star, $350/night, spa, ...
# ***********************************
# Tokyo: ~460 tokens, 12 messages
# [HumanMessage(content='Find hotels in Paris', additional_kwargs={}, response_metadata={}, id='99c65e96-5534-4425-a328-f1dd25a453b1'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 134, 'total_tokens': 158, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CttlIr1g90QSDxzitTpEcpwsMjUsc', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b838a-174c-77b1-85b1-607e4ee957ea-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_D2IQZJn7jt3FHPDSkuP8UnCD', 'type': 'tool_call'}], usage_metadata={'input_tokens': 134, 'output_tokens': 24, 'total_tokens': 158, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Paris:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='28b86944-b090-4417-b8de-445fe4b0c29a', tool_call_id='call_D2IQZJn7jt3FHPDSkuP8UnCD'), AIMessage(content='I found these options in Paris:\n\n1. Grand Hotel — 5-star, $350/night. Amenities: spa, pool, gym. (Good for luxury stays and relaxation.)\n2. City Inn — 4-star, $180/night. Amenities: business center. (Good for business travelers or mid-range comfort.)\n3. Budget Stay — 3-star, $75/night. Amenities: free Wi‑Fi. (Good low-cost option.)\n\nNext steps — which would you like?\n- Tell me travel dates and number of guests and I’ll check availability and show room types/prices.\n- Or tell me preferred neighborhood, max price, or must-have amenities and I’ll filter/search more options.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 342, 'prompt_tokens': 224, 'total_tokens': 566, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CttlLqW6GmrOKOVzlKhBIGtM3N7xR', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b838a-24d5-7283-aca3-850b9a5fccf0-0', usage_metadata={'input_tokens': 224, 'output_tokens': 342, 'total_tokens': 566, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}}), HumanMessage(content='Find hotels in London', additional_kwargs={}, response_metadata={}, id='e7a8288a-8958-424f-927b-1ccc85cc4532'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 88, 'prompt_tokens': 379, 'total_tokens': 467, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CttlSrSGXLDFfQS39tAIY4RasKfZo', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b838a-3d6a-7a72-8b58-083b47f2c2c6-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'London'}, 'id': 'call_QSJdV9iINueZnUqeEo581YhT', 'type': 'tool_call'}], usage_metadata={'input_tokens': 379, 'output_tokens': 88, 'total_tokens': 467, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}), ToolMessage(content='Hotels in London:\n    1. Grand Hotel - 5 star, $350/night, spa, ...
# ***********************************
# New York: ~376 tokens, 6 messages
# [HumanMessage(content='Here is a summary of the conversation to date:\n\n- User intent: find hotels in various cities; no travel dates, number of guests, budget, neighborhood, or amenity preferences provided yet.\n- Results already provided:\n  - Paris:\n    1) Grand Hotel — 5-star, $350/night, spa, pool, gym\n    2) City Inn — 4-star, $180/night, business center\n    3) Budget Stay — 3-star, $75/night, free Wi‑Fi\n  - London:\n    1) Grand Hotel — 5-star, $350/night, spa, pool, gym\n    2) City Inn — 4-star, $180/night, business center\n    3) Budget Stay — 3-star, $75/night, free Wi‑Fi\n- Current user request: “Find hotels in Tokyo.”', additional_kwargs={}, response_metadata={}, id='bb0b4d14-092e-4edb-95da-dcc4daa029e6'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 573, 'total_tokens': 597, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CttlXquPS4iKCDvOORQpDsDXOXEwD', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b838a-5330-7770-8c65-f1e23ef968f3-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Tokyo'}, 'id': 'call_HABcU7RH3uDqaU5YlR0I0Q3D', 'type': 'tool_call'}], usage_metadata={'input_tokens': 573, 'output_tokens': 24, 'total_tokens': 597, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Tokyo:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='b5b9998d-6eb0-4930-951e-3fd108796171', tool_call_id='call_HABcU7RH3uDqaU5YlR0I0Q3D'), AIMessage(content='Here are some hotels I found in Tokyo:\n\n1. Grand Hotel — 5-star, $350/night. Amenities: spa, pool, gym.\n2. City Inn — 4-star, $180/night. Amenities: business center.\n3. Budget Stay — 3-star, $75/night. Amenities: free Wi‑Fi.\n\nWould you like availability for particular dates, more options, or filters (price, neighborhood, amenities)?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 91, 'prompt_tokens': 663, 'total_tokens': 754, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CttlZe5QqR9icMCOn7AUnBPSGCTlp', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b838a-5b2f-7733-9570-95c6a9635f0c-0', usage_metadata={'input_tokens': 663, 'output_tokens': 91, 'total_tokens': 754, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Find hotels in New York', additional_kwargs={}, response_metadata={}, id='71f1337f-4f51-4718-a6a0-ca34a66167de'), AIMessage(content='Here are some hotels I found in New York:\n\n1. Grand Hotel — 5-star, $350/night. Amenities: spa, pool, gym.  \n2. City Inn — 4-star, $180/night. Amenities: business center.  \n3. Budget Stay — 3-star, $75/night. Amenities: free Wi‑Fi.\n\nWould you like availability for specific dates, more options, or filters (price range, neighborhood, number of guests, amenities)?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 169, 'prompt_tokens': 504, 'total_tokens': 673, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details ...
# ***********************************
# Dubai: ~471 tokens, 8 messages
# [HumanMessage(content='Here is a summary of the conversation to date:\n\n- User intent: find hotels in various cities; no travel dates, number of guests, budget, neighborhood, or amenity preferences provided yet.\n- Results already provided:\n  - Paris:\n    1) Grand Hotel — 5-star, $350/night, spa, pool, gym\n    2) City Inn — 4-star, $180/night, business center\n    3) Budget Stay — 3-star, $75/night, free Wi‑Fi\n  - London:\n    1) Grand Hotel — 5-star, $350/night, spa, pool, gym\n    2) City Inn — 4-star, $180/night, business center\n    3) Budget Stay — 3-star, $75/night, free Wi‑Fi\n- Current user request: “Find hotels in Tokyo.”', additional_kwargs={}, response_metadata={}, id='bb0b4d14-092e-4edb-95da-dcc4daa029e6'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 573, 'total_tokens': 597, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CttlXquPS4iKCDvOORQpDsDXOXEwD', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b838a-5330-7770-8c65-f1e23ef968f3-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Tokyo'}, 'id': 'call_HABcU7RH3uDqaU5YlR0I0Q3D', 'type': 'tool_call'}], usage_metadata={'input_tokens': 573, 'output_tokens': 24, 'total_tokens': 597, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Tokyo:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='b5b9998d-6eb0-4930-951e-3fd108796171', tool_call_id='call_HABcU7RH3uDqaU5YlR0I0Q3D'), AIMessage(content='Here are some hotels I found in Tokyo:\n\n1. Grand Hotel — 5-star, $350/night. Amenities: spa, pool, gym.\n2. City Inn — 4-star, $180/night. Amenities: business center.\n3. Budget Stay — 3-star, $75/night. Amenities: free Wi‑Fi.\n\nWould you like availability for particular dates, more options, or filters (price, neighborhood, amenities)?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 91, 'prompt_tokens': 663, 'total_tokens': 754, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CttlZe5QqR9icMCOn7AUnBPSGCTlp', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b838a-5b2f-7733-9570-95c6a9635f0c-0', usage_metadata={'input_tokens': 663, 'output_tokens': 91, 'total_tokens': 754, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Find hotels in New York', additional_kwargs={}, response_metadata={}, id='71f1337f-4f51-4718-a6a0-ca34a66167de'), AIMessage(content='Here are some hotels I found in New York:\n\n1. Grand Hotel — 5-star, $350/night. Amenities: spa, pool, gym.  \n2. City Inn — 4-star, $180/night. Amenities: business center.  \n3. Budget Stay — 3-star, $75/night. Amenities: free Wi‑Fi.\n\nWould you like availability for specific dates, more options, or filters (price range, neighborhood, number of guests, amenities)?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 169, 'prompt_tokens': 504, 'total_tokens': 673, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details ...
# ***********************************
# Singapore: ~478 tokens, 5 messages
# [HumanMessage(content='Here is a summary of the conversation to date:\n\n- User goal: find hotels in multiple cities.\n- Missing info (not yet provided): travel dates, number of guests, budget, preferred neighborhoods, amenities.\n- Hotels already provided:\n  - Paris:\n    1) Grand Hotel — 5-star, $350/night, spa, pool, gym\n    2) City Inn — 4-star, $180/night, business center\n    3) Budget Stay — 3-star, $75/night, free Wi‑Fi\n  - London:\n    1) Grand Hotel — 5-star, $350/night, spa, pool, gym\n    2) City Inn — 4-star, $180/night, business center\n    3) Budget Stay — 3-star, $75/night, free Wi‑Fi\n  - Tokyo:\n    1) Grand Hotel — 5-star, $350/night, spa, pool, gym\n    2) City Inn — 4-star, $180/night, business center\n    3) Budget Stay — 3-star, $75/night, free Wi‑Fi\n  - New York:\n    1) Grand Hotel — 5-star, $350/night, spa, pool, gym\n    2) City Inn — 4-star, $180/night, business center\n    3) Budget Stay — 3-star, $75/night, free Wi‑Fi\n- Assistant has asked for specifics (dates, guests, budget, neighborhood, amenities) to refine/confirm availability; awaiting user’s details.', additional_kwargs={}, response_metadata={}, id='e8cfc6b1-c545-4865-99f6-317bad6fd530'), HumanMessage(content='Find hotels in Dubai', additional_kwargs={}, response_metadata={}, id='2dd88cf9-aedd-4478-b6df-a98ad8f6d97b'), AIMessage(content='Here are some hotels I found in Dubai:\n\n1. Grand Hotel — 5-star, $350/night. Amenities: spa, pool, gym.  \n2. City Inn — 4-star, $180/night. Amenities: business center.  \n3. Budget Stay — 3-star, $75/night. Amenities: free Wi‑Fi.\n\nWould you like availability for specific dates, more options, or filters (price range, neighborhood, number of guests, amenities)?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 168, 'prompt_tokens': 614, 'total_tokens': 782, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CttluXMAOq5EUNEwZtcHAXi6CQTwr', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b838a-ab59-7c01-95cb-bdd1b828fbdd-0', usage_metadata={'input_tokens': 614, 'output_tokens': 168, 'total_tokens': 782, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}), HumanMessage(content='Find hotels in Singapore', additional_kwargs={}, response_metadata={}, id='86ae6236-3899-4f35-9f93-cb3f1fa1a3d0'), AIMessage(content='Here are some hotels in Singapore:\n\n1) Grand Hotel — 5-star, $350/night. Amenities: spa, pool, gym.  \n2) City Inn — 4-star, $180/night. Amenities: business center.  \n3) Budget Stay — 3-star, $75/night. Amenities: free Wi‑Fi.\n\nWould you like me to check availability for specific dates, filter by price or neighborhood, or show more options/amenities? If yes, please tell me your travel dates, number of guests, budget, and any must-have amenities.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 316, 'prompt_tokens': 575, 'total_tokens': 891, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CttmBshZ0l2sVqIo14S0qhooi6wAz', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b838a-effc-79d1-9d41-0075909378f7-0', usage_metadata={'input_tokens': 575, 'output_tokens': 316, 'total_tokens': 891, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}})]
# ***********************************

# %% [markdown]
# ### Human In the Loop MiddleWare

# %% [markdown]
# Pause agent execution for human approval, editing, or rejection of tool calls before they execute. Human-in-the-loop is useful for the following:
# - High-stakes operations requiring human approval (e.g. database writes, financial transactions).
# - Compliance workflows where human oversight is mandatory.
# - Long-running conversations where human feedback guides the agent.

# %%
def read_email_tool(email_id: str) -> str:
    """Mock function to read an email by its ID."""
    return f"Email content for ID: {email_id}"

def send_email_tool(recipient: str, subject: str, body: str) -> str:
    """Mock function to send an email."""
    return f"Email sent to {recipient} with subject '{subject}'"

# %%
from langchain.agents.middleware import HumanInTheLoopMiddleware
agent = create_agent(
    model="gpt-4o",
    tools=[read_email_tool,send_email_tool],
    checkpointer=InMemorySaver(),
    middleware=[
        HumanInTheLoopMiddleware(
            interrupt_on={
                "send_email_tool": {
                    "allowed_decisions": ["approve", "edit", "reject"],
                },
                "read_email_tool": False,
            }
        ),
    ],
)

# %%
config = {"configurable": {"thread_id": "test-edit"}}

# Step 1: Request (with wrong info)
result = agent.invoke(
    {"messages": [HumanMessage(content="Send email to wrong@email.com with subject 'Test' and body 'Hello'")]},
    config=config
)

# %%
result
# Out:
# {'messages': [HumanMessage(content="Send email to wrong@email.com with subject 'Test' and body 'Hello'", additional_kwargs={}, response_metadata={}, id='a5fb4423-bf34-4b51-8fe7-1bd15df8ba0b'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 95, 'total_tokens': 120, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_deacdd5f6f', 'id': 'chatcmpl-CttnJjjgElc3aA3fBXr2A2yjlhEMR', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b838b-fd4c-70e1-936e-0a5bd89884d5-0', tool_calls=[{'name': 'send_email_tool', 'args': {'recipient': 'wrong@email.com', 'subject': 'Test', 'body': 'Hello'}, 'id': 'call_wmb6YcXvqbC3IHPoov07jg05', 'type': 'tool_call'}], usage_metadata={'input_tokens': 95, 'output_tokens': 25, 'total_tokens': 120, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})],
#  '__interrupt__': [Interrupt(value={'action_requests': [{'name': 'send_email_tool', 'args': {'recipient': 'wrong@email.com', 'subject': 'Test', 'body': 'Hello'}, 'description': "Tool execution requires approval\n\nTool: send_email_tool\nArgs: {'recipient': 'wrong@email.com', 'subject': 'Test', 'body': 'Hello'}"}], 'review_configs': [{'action_name': 'send_email_tool', 'allowed_decisions': ['approve', 'edit', 'reject']}]}, id='d57856d4d7fd46afae744179af1efe2d')]}

# %%
from langgraph.types import Command
# Step 2: Edit and approve
if "__interrupt__" in result:
    print("⏸️ Paused! Editing...")
    
    result = agent.invoke(
        Command(
            resume={
                "decisions": [
                    {
                        "type": "edit",
                        "edited_action": {
                            "name": "send_email_tool",      # Tool name
                            "args": {                   # New arguments
                                "recipient": "correct@email.com",
                                "subject": "Corrected Subject",
                                "body": "This was edited by human before sending"
                            }
                        }
                    }
                ]
            }
        ),
        config=config
    )
    
    print(f"✏️ Result: {result['messages'][-1].content}")
# Out:
# ⏸️ Paused! Editing...
# ✏️ Result: I mistakenly executed the email sending to a corrected address. If you want to proceed with your original request, please confirm the email details again, and I'll send it accordingly.
